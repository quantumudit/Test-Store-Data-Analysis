# %% [markdown]
# # Data Preprocessing

# %%
import os
print(f"Current working directory: {os.path.basename(os.getcwd())}")

# Change to root directory
os.chdir("../")
print(f"Current working directory (Changed): {os.path.basename(os.getcwd())}")
# Out:
# Current working directory: notebooks
# Current working directory (Changed): Test-Store-Data-Analysis

# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import json

# module setup
# %matplotlib inline
pd.options.display.precision = 3
warnings.filterwarnings("ignore")

# %%
from src.constants import CONFIGS
from src.utils.basic_utils import read_yaml

# %%
configs = read_yaml(CONFIGS).data_preprocessing
dict(configs)
# Out:
# [2024-02-04 01:15:58 PM]:ProjectLogger INFO:basic_utils    39 - yaml file: conf\configs.yaml loaded successfully
# {'scraped_data_path': 'data/external/scraped_products.csv',
#  'processed_data_path': 'data/processed/products.csv'}

# %%
scraped_df = pd.read_csv(configs.scraped_data_path)
scraped_df.sample(5)
# Out:
#                      title   price in_stocks   sku                  category  \
# 78   Helios Endurance Tank  £32.00       NaN  MT04                     Tanks
# 124     Nora Practice Tank  £39.00       NaN  WT03  Erin Recommends|Clothing
# 142  Riona Full Zip Jacket  £60.00       NaN  WJ05                   Jackets
# 133           Portia Capri  £49.00       NaN  WP13  Erin Recommends|Clothing
# 50            Diana Tights  £59.00       NaN  WP06  Erin Recommends|Clothing
#
#                                            description  \
# 78   When training pushes your limits, you need gea...
# 124  A closet go-to, the Nora Practice Tank can be ...
# 142  The Riona Basic Zip Jacket makes the perfect e...
# 133  From yoga at dawn to evenings curled up with a...
# 50   Perfect for hot bikram session or cool-down st...
#
#                                     product_image_link  \
# 78   https://gopher1.extrkt.com/wp-content/uploads/...
# 124  https://gopher1.extrkt.com/wp-content/uploads/...
# 142  https://gopher1.extrkt.com/wp-content/uploads/...
# 133  https://gopher1.extrkt.com/wp-content/uploads/...
# 50   https://gopher1.extrkt.com/wp-content/uploads/...
#
#                                        additional_info  \
# 78        {'Size': 'XS, S, M, L, XL', 'Color': 'Blue'}
# 124  {'Size': 'XS, S, M, L, XL', 'Color': 'Orange, ...
# 142  {'Size': 'XS, S, M, L, XL', 'Color': 'Brown, G...
# 133  {'Size': '28, 29', 'Color': 'Blue, Green, Oran...
# 50   {'Size': '28, 29', 'Color': 'Black, Blue, Oran...
#
#                                           product_link            scrape_ts
# 78   https://gopher1.extrkt.com/?product=helios-end...  2024-02-03 22:52:57
# 124  https://gopher1.extrkt.com/?product=nora-pract...  2024-02-03 23:14:25
# 142  https://gopher1.extrkt.com/?product=riona-full...  2024-02-03 23:15:22
# 133   https://gopher1.extrkt.com/?product=portia-capri  2024-02-03 23:14:53
# 50    https://gopher1.extrkt.com/?product=diana-tights  2024-02-03 22:51:29

# %%
# if we don't split the "category" but keep it as it is

def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    
    df = df[df["sku"] != "test-product"]
    df["price"] = df["price"].str.replace("£", "")
    df["in_stocks"] = df["in_stocks"].str.replace(" in stock", "")
    df["category"] = df["category"].str.replace("|", " ")
    
    # handled and removed in scraping (hot fix line: TO BE REMOVED)
    df['price'] = df['price'].str.replace("32.0024.00", "24.00")
    # ---- #
    df = df.astype({
        "price": "float32", 
        "in_stocks": "float32", 
        "scrape_ts": "datetime64[ns]"})
    
    info_list = []
    for _, row in df[["sku", "additional_info"]].iterrows():
        additional_info_dict = json.loads(row["additional_info"].replace("'", "\""))
        additional_info_dict["sku"] = row["sku"]
        info_list.append(additional_info_dict)
        
    info_df = pd.DataFrame(info_list)
    info_df.columns = map(lambda x: x.lower(), info_df.columns)
    
    # Column order required
    rearranged_col_list = [
        "sku", "title", "price_in_pounds", 
        "category", "description", "in_stocks",
        "product_image_link", "size", "color",
        "activity", "gender", "material", "pattern",
        "strap", "style", "product_link", "scrape_ts"
        ]
    
    final_df = (
        pd.merge(df, info_df, on="sku", how="inner")
        .drop(columns="additional_info")
        .rename(columns={"price": "price_in_pounds"})
        .reindex(columns = rearranged_col_list)
        .drop_duplicates(subset=["sku"])
        .reset_index(drop=True)
    )
    return final_df

# %%
main_df = clean_data(df=scraped_df)
main_df
# Out:
#          sku                   title  price_in_pounds  \
# 0       MH09       Abominable Hoodie             69.0
# 1       WJ08    Adrienne Trek Jacket             57.0
# 2       WP07              Aeon Capri             48.0
# 3       MS01  Aero Daily Fitness Tee             24.0
# 4       MP11         Aether Gym Pant             74.0
# ..       ...                     ...              ...
# 186  24-MB05  Wayfarer Messenger Bag             45.0
# 187     MP08      Zeppelin Yoga Pant             82.0
# 188  24-UG04          Zing Jump Rope             12.0
# 189     WT02                Zoe Tank             29.0
# 190     MS06          Zoltan Gym Tee             29.0
#
#                               category  \
# 0                Hoodies & Sweatshirts
# 1             Erin Recommends Clothing
# 2         Performance Fabrics Clothing
# 3                                 Tees
# 4             Erin Recommends Clothing
# ..                                 ...
# 186           New Luma Yoga Collection
# 187  New Luma Yoga Collection Clothing
# 188                  Fitness Equipment
# 189                       Bras & Tanks
# 190                               Tees
#
#                                            description  in_stocks  \
# 0    It took CoolTech™ weather apparel know-how and...        NaN
# 1    You’re ready for a cross-country jog or a coff...        NaN
# 2    Reach for the stars and beyond in these Aeon C...        NaN
# 3    Need an everyday action tee that helps keep yo...        NaN
# 4    The Aether Gym Pant is built for the studio, b...        NaN
# ..                                                 ...        ...
# 186  Perfect for class, work or the gym, the Wayfar...      100.0
# 187  Climb every mountain, or hold every pose, in t...        NaN
# 188  One of the world’s simplest and most portable ...      100.0
# 189  The Zoe Tank leads with eye-catching fitness-p...        NaN
# 190  This short-sleeve wonder works twice as hard t...        NaN
#
#                                     product_image_link             size  \
# 0    https://gopher1.extrkt.com/wp-content/uploads/...  XS, S, M, L, XL
# 1    https://gopher1.extrkt.com/wp-content/uploads/...  XS, S, M, L, XL
# 2    https://gopher1.extrkt.com/wp-content/uploads/...           28, 29
# 3    https://gopher1.extrkt.com/wp-content/uploads/...  XS, S, M, L, XL
# 4    https://gopher1.extrkt.com/wp-content/uploads/...   32, 33, 34, 36
# ..                                                 ...              ...
# 186  https://gopher1.extrkt.com/wp-content/uploads/...              NaN
# 187  https://gopher1.extrkt.com/wp-content/uploads/...   32, 33, 34, 36
# 188  https://gopher1.extrkt.com/wp-content/uploads/...              NaN
# 189  https://gopher1.extrkt.com/wp-content/uploads/...  XS, S, M, L, XL
# 190  https://gopher1.extrkt.com/wp-content/uploads/...  XS, S, M, L, XL
#
#                      color                activity              gender  \
# 0         Blue, Green, Red                     NaN                 NaN
# 1     Gray, Orange, Purple                     NaN                 NaN
# 2      Black, Blue, Orange                     NaN                 NaN
# 3     Black, Brown, Yellow                     NaN                 NaN
# 4       Blue, Brown, Green                     NaN                 NaN
# ..                     ...                     ...                 ...
# 186                    NaN  Gym, Overnight, Travel                 NaN
# 187       Blue, Green, Red                     NaN                 NaN
# 188                    NaN                     Gym  Men, Women, Unisex
# 189  Green, Orange, Yellow                     NaN                 NaN
# 190    Blue, Green, Yellow                     NaN                 NaN
#
#              material pattern  \
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
# ..                ...     ...
# 186  Nylon, Polyester   Solid
# 187               NaN     NaN
# 188  Leather, Plastic     NaN
# 189               NaN     NaN
# 190               NaN     NaN
#
#                                                 strap              style  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# ..                                                ...                ...
# 186  Adjustable, Detachable, Double, Padded, Shoulder  Messenger, Laptop
# 187                                               NaN                NaN
# 188                                               NaN                NaN
# 189                                               NaN                NaN
# 190                                               NaN                NaN
#
#                                           product_link           scrape_ts
# 0    https://gopher1.extrkt.com/?product=abominable... 2024-02-03 22:48:50
# 1    https://gopher1.extrkt.com/?product=adrienne-t... 2024-02-03 22:48:54
# 2       https://gopher1.extrkt.com/?product=aeon-capri 2024-02-03 22:48:57
# 3    https://gopher1.extrkt.com/?product=aero-daily... 2024-02-03 22:49:01
# 4    https://gopher1.extrkt.com/?product=aether-gym... 2024-02-03 22:49:04
# ..                                                 ...                 ...
# 186  https://gopher1.extrkt.com/?product=wayfarer-m... 2024-02-03 23:17:41
# 187  https://gopher1.extrkt.com/?product=zeppelin-y... 2024-02-03 23:17:43
# 188  https://gopher1.extrkt.com/?product=zing-jump-... 2024-02-03 23:17:47
# 189       https://gopher1.extrkt.com/?product=zoe-tank 2024-02-03 23:17:50
# 190  https://gopher1.extrkt.com/?product=zoltan-gym... 2024-02-03 23:17:54
#
# [191 rows x 17 columns]

# %%
main_df.columns.to_list()
# Out:
# ['sku',
#  'title',
#  'price_in_pounds',
#  'category',
#  'description',
#  'in_stocks',
#  'product_image_link',
#  'size',
#  'color',
#  'activity',
#  'gender',
#  'material',
#  'pattern',
#  'strap',
#  'style',
#  'product_link',
#  'scrape_ts']

# %%
# Out:
# ['title',
#  'price_in_pounds',
#  'in_stocks',
#  'sku',
#  'category',
#  'description',
#  'product_image_link',
#  'product_link',
#  'scrape_ts',
#  'size',
#  'color',
#  'activity',
#  'gender',
#  'material',
#  'pattern',
#  'strap',
#  'style']

# %%
["sku", "title", "price_in_pounds",
"category", "description", "in_stocks",
"product_image_link", "size", "color",
"activity", "gender", "material", "pattern",
"strap", "style", "product_link", "scrape_ts"
]

# %%
# if we want to split the category

def clean_data_2(df: pd.DataFrame) -> pd.DataFrame:
    
    df = df[df["sku"] != "test-product"]
    df["price"] = df["price"].str.replace("£", "")
    df["in_stocks"] = df["in_stocks"].str.replace(" in stock", "")
    df = df.astype({
        "price": "float32", 
        "in_stocks": "float32", 
        "scrape_ts": "datetime64[ns]"})
    
    sub_df = (
        df["category"].str.split(pat='|', expand=True)
        .rename(columns={0: "category", 1: "category_group"})
        .fillna({"category_group": "Others"})
        )
    
    df = pd.concat([df.drop(columns="category"), sub_df], axis=1)
    
    info_list = []
    for _, row in df[["sku", "additional_info"]].iterrows():
        additional_info_dict = json.loads(row["additional_info"].replace("'", "\""))
        additional_info_dict["sku"] = row["sku"]
        info_list.append(additional_info_dict)
        
    info_df = pd.DataFrame(info_list)
    
    final_df = (
        pd.merge(df, info_df, on="sku", how="inner")
        .drop(columns="additional_info")
    )

# %%
sub_df = (
    scraped_df["category"].str.split(pat='|', expand=True)
    .rename(columns={0: "category", 1: "category_group"})
    .fillna({"category_group": "Others"})
)

df = pd.concat([scraped_df.drop(columns="category"), sub_df], axis=1)
df
# Out:
#                       title   price     in_stocks      sku  \
# 0         Abominable Hoodie  £69.00           NaN     MH09
# 1      Adrienne Trek Jacket  £57.00           NaN     WJ08
# 2                Aeon Capri  £48.00           NaN     WP07
# 3    Aero Daily Fitness Tee  £24.00           NaN     MS01
# 4           Aether Gym Pant  £74.00           NaN     MP11
# ..                      ...     ...           ...      ...
# 188  Wayfarer Messenger Bag  £45.00  100 in stock  24-MB05
# 189      Zeppelin Yoga Pant  £82.00           NaN     MP08
# 190          Zing Jump Rope  £12.00  100 in stock  24-UG04
# 191                Zoe Tank  £29.00           NaN     WT02
# 192          Zoltan Gym Tee  £29.00           NaN     MS06
#
#                                            description  \
# 0    It took CoolTech™ weather apparel know-how and...
# 1    You’re ready for a cross-country jog or a coff...
# 2    Reach for the stars and beyond in these Aeon C...
# 3    Need an everyday action tee that helps keep yo...
# 4    The Aether Gym Pant is built for the studio, b...
# ..                                                 ...
# 188  Perfect for class, work or the gym, the Wayfar...
# 189  Climb every mountain, or hold every pose, in t...
# 190  One of the world’s simplest and most portable ...
# 191  The Zoe Tank leads with eye-catching fitness-p...
# 192  This short-sleeve wonder works twice as hard t...
#
#                                     product_image_link  \
# 0    https://gopher1.extrkt.com/wp-content/uploads/...
# 1    https://gopher1.extrkt.com/wp-content/uploads/...
# 2    https://gopher1.extrkt.com/wp-content/uploads/...
# 3    https://gopher1.extrkt.com/wp-content/uploads/...
# 4    https://gopher1.extrkt.com/wp-content/uploads/...
# ..                                                 ...
# 188  https://gopher1.extrkt.com/wp-content/uploads/...
# 189  https://gopher1.extrkt.com/wp-content/uploads/...
# 190  https://gopher1.extrkt.com/wp-content/uploads/...
# 191  https://gopher1.extrkt.com/wp-content/uploads/...
# 192  https://gopher1.extrkt.com/wp-content/uploads/...
#
#                                        additional_info  \
# 0    {'Size': 'XS, S, M, L, XL', 'Color': 'Blue, Gr...
# 1    {'Size': 'XS, S, M, L, XL', 'Color': 'Gray, Or...
# 2    {'Size': '28, 29', 'Color': 'Black, Blue, Oran...
# 3    {'Size': 'XS, S, M, L, XL', 'Color': 'Black, B...
# 4    {'Size': '32, 33, 34, 36', 'Color': 'Blue, Bro...
# ..                                                 ...
# 188  {'Activity': 'Gym, Overnight, Travel', 'Patter...
# 189  {'Size': '32, 33, 34, 36', 'Color': 'Blue, Gre...
# 190  {'Activity': 'Gym', 'Gender': 'Men, Women, Uni...
# 191  {'Size': 'XS, S, M, L, XL', 'Color': 'Green, O...
# 192  {'Size': 'XS, S, M, L, XL', 'Color': 'Blue, Gr...
#
#                                           product_link            scrape_ts  \
# 0    https://gopher1.extrkt.com/?product=abominable...  2024-02-03 22:48:50
# 1    https://gopher1.extrkt.com/?product=adrienne-t...  2024-02-03 22:48:54
# 2       https://gopher1.extrkt.com/?product=aeon-capri  2024-02-03 22:48:57
# 3    https://gopher1.extrkt.com/?product=aero-daily...  2024-02-03 22:49:01
# 4    https://gopher1.extrkt.com/?product=aether-gym...  2024-02-03 22:49:04
# ..                                                 ...                  ...
# 188  https://gopher1.extrkt.com/?product=wayfarer-m...  2024-02-03 23:17:41
# 189  https://gopher1.extrkt.com/?product=zeppelin-y...  2024-02-03 23:17:43
# 190  https://gopher1.extrkt.com/?product=zing-jump-...  2024-02-03 23:17:47
# 191       https://gopher1.extrkt.com/?product=zoe-tank  2024-02-03 23:17:50
# 192  https://gopher1.extrkt.com/?product=zoltan-gym...  2024-02-03 23:17:54
#
#                      category category_group
# 0       Hoodies & Sweatshirts         Others
# 1             Erin Recommends       Clothing
# 2         Performance Fabrics       Clothing
# 3                        Tees         Others
# 4             Erin Recommends       Clothing
# ..                        ...            ...
# 188  New Luma Yoga Collection         Others
# 189  New Luma Yoga Collection       Clothing
# 190         Fitness Equipment         Others
# 191              Bras & Tanks         Others
# 192                      Tees         Others
#
# [193 rows x 11 columns]

# %%
import pandas as pd

def clean_data(scraped_df):
    # Replace all instances of "£" with "" in column: 'price'
    scraped_df['price'] = scraped_df['price'].str.replace("£", "", case=False, regex=False)
    # Replace all instances of " in stock" with "" in column: 'in_stocks'
    scraped_df['in_stocks'] = scraped_df['in_stocks'].str.replace(" in stock", "", case=False, regex=False)
    # Replace all instances of "32.0024.00" with "24.00" in column: 'price'
    scraped_df['price'] = scraped_df['price'].str.replace("32.0024.00", "24.00", case=False, regex=False)
    # Change column type to float32 for column: 'price'
    scraped_df = scraped_df.astype({'price': 'float32'})
    # Change column type to float32 for column: 'in_stocks'
    scraped_df = scraped_df.astype({'in_stocks': 'float32'})
    # Change column type to datetime64[ns] for column: 'scrape_ts'
    scraped_df = scraped_df.astype({'scrape_ts': 'datetime64[ns]'})
    # Split text using string '|' in column: 'category'
    loc_0 = scraped_df.columns.get_loc('category')
    scraped_df_split = scraped_df['category'].str.split(pat='|', expand=True).add_prefix('category_')
    scraped_df = pd.concat([scraped_df.iloc[:, :loc_0], scraped_df_split, scraped_df.iloc[:, loc_0:]], axis=1)
    scraped_df = scraped_df.drop(columns=['category'])
    # Rename column 'category_0' to 'category'
    scraped_df = scraped_df.rename(columns={'category_0': 'category'})
    # Rename column 'category_1' to 'category_group'
    scraped_df = scraped_df.rename(columns={'category_1': 'category_group'})
    # Replace missing values with "Others" in column: 'category_group'
    scraped_df = scraped_df.fillna({'category_group': "Others"})
    return scraped_df

scraped_df_clean = clean_data(scraped_df.copy())
scraped_df_clean.head()
# Out:
#                     title  price  in_stocks   sku               category  \
# 0       Abominable Hoodie   69.0        NaN  MH09  Hoodies & Sweatshirts
# 1    Adrienne Trek Jacket   57.0        NaN  WJ08        Erin Recommends
# 2              Aeon Capri   48.0        NaN  WP07    Performance Fabrics
# 3  Aero Daily Fitness Tee   24.0        NaN  MS01                   Tees
# 4         Aether Gym Pant   74.0        NaN  MP11        Erin Recommends
#
#   category_group                                        description  \
# 0         Others  It took CoolTech™ weather apparel know-how and...
# 1       Clothing  You’re ready for a cross-country jog or a coff...
# 2       Clothing  Reach for the stars and beyond in these Aeon C...
# 3         Others  Need an everyday action tee that helps keep yo...
# 4       Clothing  The Aether Gym Pant is built for the studio, b...
#
#                                   product_image_link  \
# 0  https://gopher1.extrkt.com/wp-content/uploads/...
# 1  https://gopher1.extrkt.com/wp-content/uploads/...
# 2  https://gopher1.extrkt.com/wp-content/uploads/...
# 3  https://gopher1.extrkt.com/wp-content/uploads/...
# 4  https://gopher1.extrkt.com/wp-content/uploads/...
#
#                                      additional_info  \
# 0  {'Size': 'XS, S, M, L, XL', 'Color': 'Blue, Gr...
# 1  {'Size': 'XS, S, M, L, XL', 'Color': 'Gray, Or...
# 2  {'Size': '28, 29', 'Color': 'Black, Blue, Oran...
# 3  {'Size': 'XS, S, M, L, XL', 'Color': 'Black, B...
# 4  {'Size': '32, 33, 34, 36', 'Color': 'Blue, Bro...
#
#                                         product_link           scrape_ts
# 0  https://gopher1.extrkt.com/?product=abominable... 2024-02-03 22:48:50
# 1  https://gopher1.extrkt.com/?product=adrienne-t... 2024-02-03 22:48:54
# 2     https://gopher1.extrkt.com/?product=aeon-capri 2024-02-03 22:48:57
# 3  https://gopher1.extrkt.com/?product=aero-daily... 2024-02-03 22:49:01
# 4  https://gopher1.extrkt.com/?product=aether-gym... 2024-02-03 22:49:04

# %%
def clean_data(scraped_df_clean):
    # Drop duplicate rows in column: 'sku'
    scraped_df_clean = scraped_df_clean.drop_duplicates(subset=['sku'])
    # Select columns: 'sku', 'additional_info'
    scraped_df_clean = scraped_df_clean.loc[:, ['sku', 'additional_info']]
    return scraped_df_clean

scraped_df_clean_1 = clean_data(scraped_df_clean.copy())
scraped_df_clean_1.head()
# Out:
#     sku                                    additional_info
# 0  MH09  {'Size': 'XS, S, M, L, XL', 'Color': 'Blue, Gr...
# 1  WJ08  {'Size': 'XS, S, M, L, XL', 'Color': 'Gray, Or...
# 2  WP07  {'Size': '28, 29', 'Color': 'Black, Blue, Oran...
# 3  MS01  {'Size': 'XS, S, M, L, XL', 'Color': 'Black, B...
# 4  MP11  {'Size': '32, 33, 34, 36', 'Color': 'Blue, Bro...

# %%
import json

# %%
info_list = []
for idx, row in scraped_df_clean[["sku", "additional_info"]].iterrows():
    additional_info_dict = json.loads(row["additional_info"].replace("'", "\""))
    additional_info_dict["sku"] = row["sku"]
    info_list.append(additional_info_dict)


info_df = pd.DataFrame(info_list)
info_df.head()
# Out:
#               Size                 Color   sku Activity Gender Material  \
# 0  XS, S, M, L, XL      Blue, Green, Red  MH09      NaN    NaN      NaN
# 1  XS, S, M, L, XL  Gray, Orange, Purple  WJ08      NaN    NaN      NaN
# 2           28, 29   Black, Blue, Orange  WP07      NaN    NaN      NaN
# 3  XS, S, M, L, XL  Black, Brown, Yellow  MS01      NaN    NaN      NaN
# 4   32, 33, 34, 36    Blue, Brown, Green  MP11      NaN    NaN      NaN
#
#   Pattern Strap Style
# 0     NaN   NaN   NaN
# 1     NaN   NaN   NaN
# 2     NaN   NaN   NaN
# 3     NaN   NaN   NaN
# 4     NaN   NaN   NaN

# %%
info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Size      158 non-null    object
#  1   Color     155 non-null    object
#  2   sku       192 non-null    object
#  3   Activity  44 non-null     object
#  4   Gender    30 non-null     object
#  5   Material  44 non-null     object
#  6   Pattern   14 non-null     object
#  7   Strap     14 non-null     object
#  8   Style     14 non-null     object
# dtypes: object(9)
# memory usage: 13.6+ KB

# %%
main_df = pd.merge(scraped_df_clean, info_df, on='sku', how='inner')
main_df
# Out:
#                       title  price  in_stocks      sku  \
# 0         Abominable Hoodie   69.0        NaN     MH09
# 1      Adrienne Trek Jacket   57.0        NaN     WJ08
# 2                Aeon Capri   48.0        NaN     WP07
# 3    Aero Daily Fitness Tee   24.0        NaN     MS01
# 4           Aether Gym Pant   74.0        NaN     MP11
# ..                      ...    ...        ...      ...
# 188  Wayfarer Messenger Bag   45.0      100.0  24-MB05
# 189      Zeppelin Yoga Pant   82.0        NaN     MP08
# 190          Zing Jump Rope   12.0      100.0  24-UG04
# 191                Zoe Tank   29.0        NaN     WT02
# 192          Zoltan Gym Tee   29.0        NaN     MS06
#
#                      category category_group  \
# 0       Hoodies & Sweatshirts         Others
# 1             Erin Recommends       Clothing
# 2         Performance Fabrics       Clothing
# 3                        Tees         Others
# 4             Erin Recommends       Clothing
# ..                        ...            ...
# 188  New Luma Yoga Collection         Others
# 189  New Luma Yoga Collection       Clothing
# 190         Fitness Equipment         Others
# 191              Bras & Tanks         Others
# 192                      Tees         Others
#
#                                            description  \
# 0    It took CoolTech™ weather apparel know-how and...
# 1    You’re ready for a cross-country jog or a coff...
# 2    Reach for the stars and beyond in these Aeon C...
# 3    Need an everyday action tee that helps keep yo...
# 4    The Aether Gym Pant is built for the studio, b...
# ..                                                 ...
# 188  Perfect for class, work or the gym, the Wayfar...
# 189  Climb every mountain, or hold every pose, in t...
# 190  One of the world’s simplest and most portable ...
# 191  The Zoe Tank leads with eye-catching fitness-p...
# 192  This short-sleeve wonder works twice as hard t...
#
#                                     product_image_link  \
# 0    https://gopher1.extrkt.com/wp-content/uploads/...
# 1    https://gopher1.extrkt.com/wp-content/uploads/...
# 2    https://gopher1.extrkt.com/wp-content/uploads/...
# 3    https://gopher1.extrkt.com/wp-content/uploads/...
# 4    https://gopher1.extrkt.com/wp-content/uploads/...
# ..                                                 ...
# 188  https://gopher1.extrkt.com/wp-content/uploads/...
# 189  https://gopher1.extrkt.com/wp-content/uploads/...
# 190  https://gopher1.extrkt.com/wp-content/uploads/...
# 191  https://gopher1.extrkt.com/wp-content/uploads/...
# 192  https://gopher1.extrkt.com/wp-content/uploads/...
#
#                                        additional_info  \
# 0    {'Size': 'XS, S, M, L, XL', 'Color': 'Blue, Gr...
# 1    {'Size': 'XS, S, M, L, XL', 'Color': 'Gray, Or...
# 2    {'Size': '28, 29', 'Color': 'Black, Blue, Oran...
# 3    {'Size': 'XS, S, M, L, XL', 'Color': 'Black, B...
# 4    {'Size': '32, 33, 34, 36', 'Color': 'Blue, Bro...
# ..                                                 ...
# 188  {'Activity': 'Gym, Overnight, Travel', 'Patter...
# 189  {'Size': '32, 33, 34, 36', 'Color': 'Blue, Gre...
# 190  {'Activity': 'Gym', 'Gender': 'Men, Women, Uni...
# 191  {'Size': 'XS, S, M, L, XL', 'Color': 'Green, O...
# 192  {'Size': 'XS, S, M, L, XL', 'Color': 'Blue, Gr...
#
#                                           product_link           scrape_ts  \
# 0    https://gopher1.extrkt.com/?product=abominable... 2024-02-03 22:48:50
# 1    https://gopher1.extrkt.com/?product=adrienne-t... 2024-02-03 22:48:54
# 2       https://gopher1.extrkt.com/?product=aeon-capri 2024-02-03 22:48:57
# 3    https://gopher1.extrkt.com/?product=aero-daily... 2024-02-03 22:49:01
# 4    https://gopher1.extrkt.com/?product=aether-gym... 2024-02-03 22:49:04
# ..                                                 ...                 ...
# 188  https://gopher1.extrkt.com/?product=wayfarer-m... 2024-02-03 23:17:41
# 189  https://gopher1.extrkt.com/?product=zeppelin-y... 2024-02-03 23:17:43
# 190  https://gopher1.extrkt.com/?product=zing-jump-... 2024-02-03 23:17:47
# 191       https://gopher1.extrkt.com/?product=zoe-tank 2024-02-03 23:17:50
# 192  https://gopher1.extrkt.com/?product=zoltan-gym... 2024-02-03 23:17:54
#
#                 Size                  Color                Activity  \
# 0    XS, S, M, L, XL       Blue, Green, Red                     NaN
# 1    XS, S, M, L, XL   Gray, Orange, Purple                     NaN
# 2             28, 29    Black, Blue, Orange                     NaN
# 3    XS, S, M, L, XL   Black, Brown, Yellow                     NaN
# 4     32, 33, 34, 36     Blue, Brown, Green                     NaN
# ..               ...                    ...                     ...
# 188              NaN                    NaN  Gym, Overnight, Travel
# 189   32, 33, 34, 36       Blue, Green, Red                     NaN
# 190              NaN                    NaN                     Gym
# 191  XS, S, M, L, XL  Green, Orange, Yellow                     NaN
# 192  XS, S, M, L, XL    Blue, Green, Yellow                     NaN
#
#                  Gender          Material Pattern  \
# 0                   NaN               NaN     NaN
# 1                   NaN               NaN     NaN
# 2                   NaN               NaN     NaN
# 3                   NaN               NaN     NaN
# 4                   NaN               NaN     NaN
# ..                  ...               ...     ...
# 188                 NaN  Nylon, Polyester   Solid
# 189                 NaN               NaN     NaN
# 190  Men, Women, Unisex  Leather, Plastic     NaN
# 191                 NaN               NaN     NaN
# 192                 NaN               NaN     NaN
#
#                                                 Strap              Style
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# ..                                                ...                ...
# 188  Adjustable, Detachable, Double, Padded, Shoulder  Messenger, Laptop
# 189                                               NaN                NaN
# 190                                               NaN                NaN
# 191                                               NaN                NaN
# 192                                               NaN                NaN
#
# [193 rows x 19 columns]
